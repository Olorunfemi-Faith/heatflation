# %%
import psycopg2

connection = psycopg2.connect(
    dbname="Heatflation", 
    user="postgres", 
    password="TITI@2020")

# %%
# Create database courier, command it to fetch list of tables and display them
cursor = connection.cursor()


cursor.execute("""
    SELECT table_name 
    FROM information_schema.tables 
    WHERE table_schema = 'public';
""")


tables = cursor.fetchall()
print("Here are your tables:")
for table in tables:
    print(f"- {table[0]}")
# Out:
# Here are your tables:
# - cpi
# - food_prices
# - ndvi
# - rainfall
# - v1_combined_raw_base
# - v2_real_prices
# - v1_join
# - v2_join
# - v3_base
# - v4_trace_pipeline
# - v5_trace_pipeline
# - v6_trace_pipeline
# - v7_heatflation_model
# - fin_heat

# %%
import pandas as pd

# Select your data and load. confirm first 5 rows
query = "SELECT * FROM fin_heat;"

df = pd.read_sql_query(query, connection)

df.head()
# Out:
# C:\Users\USER\anaconda3\AnacondaPath9\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     state  year  month  current_real_price  log_real_price  \
# 0  kaduna  2013     12               46.69        3.843530
# 1  kaduna  2014      1               44.58        3.797285
# 2  kaduna  2014      2               38.92        3.661508
# 3  kaduna  2014      7               26.58        3.280159
# 4  kaduna  2014      9               24.21        3.186766
#
#    current_vim_anomaly  current_rfh_anomaly  vim_1m_ago  vim_2m_ago  \
# 0              -0.0089                 0.08     -0.0130     -0.0056
# 1               0.0009                 0.32     -0.0089     -0.0130
# 2               0.0068                 0.03      0.0009     -0.0089
# ...

# %%
list(df.columns)
# Out:
# ['state',
#  'year',
#  'month',
#  'current_real_price',
#  'log_real_price',
#  'current_vim_anomaly',
#  'current_rfh_anomaly',
#  'vim_1m_ago',
#  'vim_2m_ago',
#  'vim_3m_ago',
#  'vim_4m_ago',
#  'rfh_1m_ago',
#  'rfh_2m_ago',
#  'rfh_3m_ago',
#  'rfh_4m_ago']

# %%
# 1. Select the columns to check correlations
analysis_cols = [
    'log_real_price',
    'current_vim_anomaly', 'vim_1m_ago', 'vim_2m_ago', 'vim_3m_ago', 'vim_4m_ago',
    'current_rfh_anomaly', 'rfh_1m_ago', 'rfh_2m_ago', 'rfh_3m_ago', 'rfh_4m_ago'
]

# 2. Calculate the correlation matrix
correlation_matrix = df[analysis_cols].corr()

# 3. Look at how climate lags line up specifically with logged prices
correlation_matrix[['log_real_price']]
# Out:
#                      log_real_price
# log_real_price             1.000000
# current_vim_anomaly       -0.137990
# vim_1m_ago                -0.201449
# vim_2m_ago                -0.236743
# vim_3m_ago                -0.213066
# vim_4m_ago                -0.168313
# current_rfh_anomaly       -0.046157
# rfh_1m_ago                -0.034380
# rfh_2m_ago                 0.005895
# rfh_3m_ago                -0.019660
# rfh_4m_ago                -0.029910

# %%
# 1. calculating correlations
rfh_cols = ['current_rfh_anomaly', 'rfh_1m_ago', 'rfh_2m_ago', 'rfh_3m_ago', 'rfh_4m_ago']


rfh_correlations = df[rfh_cols + ['log_real_price']].corr()['log_real_price'].drop('log_real_price')


print("Rainfall Correlations with Log Real Price:")
print(rfh_correlations)
# Out:
# Rainfall Correlations with Log Real Price:
# current_rfh_anomaly   -0.046157
# rfh_1m_ago            -0.034380
# rfh_2m_ago             0.005895
# rfh_3m_ago            -0.019660
# rfh_4m_ago            -0.029910
# Name: log_real_price, dtype: float64

# %%
# DEPICTING BIOLOGICAL AND ECONOMICAL LAG

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# Chronological lag order (Past -> Present)
rfh_lags = ['rfh_4m_ago', 'rfh_3m_ago', 'rfh_2m_ago', 'rfh_1m_ago', 'current_rfh_anomaly']
vim_lags = ['vim_4m_ago', 'vim_3m_ago', 'vim_2m_ago', 'vim_1m_ago', 'current_vim_anomaly']
labels = ['4 Months Ago', '3 Months Ago', '2 Months Ago', '1 Month Ago', 'Current Month']

# 1. BIOLOGICAL LAG: Rainfall Anomaly vs VIM (Crop Health)
# Positive correlation expected: Less rain = Lower VIM (poorer crop health)
bio_corr = [df[rfh_lags[i]].corr(df['current_vim_anomaly']) for i in range(5)]

axes[0].plot(labels, bio_corr, marker='o', color='#2ca02c', linewidth=2.5, markersize=7)
axes[0].axhline(0, color='red', linestyle='--', alpha=0.6)
axes[0].set_title("1. Biological Lag: Rainfall Deficits -> Vegetation Health (VIM)", fontweight='bold')
axes[0].set_ylabel("Correlation (r)\n[RFH vs. VIM]", fontweight='bold')

# 2. ECONOMIC LAG: VIM (Crop Health) vs Log Real Price
# Negative correlation expected: Lower VIM (poor crops) = Higher Real Price
econ_corr = [df[vim_lags[i]].corr(df['log_real_price']) for i in range(5)]

axes[1].plot(labels, econ_corr, marker='s', color='#d62728', linewidth=2.5, markersize=7)
axes[1].axhline(0, color='red', linestyle='--', alpha=0.6)
axes[1].set_title("2. Economic Lag: Vegetation Health (VIM) -> Market Price Spike", fontweight='bold')
axes[1].set_ylabel("Correlation (r)\n[VIM vs. Price]", fontweight='bold')
axes[1].set_xlabel("Transmission Timeline (Past -> Present)", fontweight='bold')

plt.tight_layout()
plt.show()

# %%
#MONTHS PRONE TO HEATFLATION


import matplotlib.pyplot as plt
import seaborn as sns

# Clean, single standalone figure setup
plt.figure(figsize=(9, 5))
sns.set_theme(style="whitegrid")

# Calculate monthly average log real price
monthly_avg = df.groupby('month')['log_real_price'].mean().reset_index()

# Plot single bar chart
ax = sns.barplot(data=monthly_avg, x='month', y='log_real_price', palette="YlOrRd")

# Highlight month names instead of raw numbers
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(ticks=range(12), labels=month_names, fontweight='bold')

# DRAMATIC EFFECT: Zoom the y-axis to start near the minimum value
min_val = monthly_avg['log_real_price'].min() * 0.98
max_val = monthly_avg['log_real_price'].max() * 1.02
plt.ylim(min_val, max_val)

# Formatting
plt.title("Seasonal Price Spikes: Peak Heatflation Months", fontsize=12, fontweight='bold')
plt.xlabel("Month of Year", fontsize=10)
plt.ylabel("Mean Log Real Price (Zoomed)", fontsize=10)

plt.tight_layout()
plt.show()

# %%
#KADUNA VS KANO

import matplotlib.pyplot as plt
import seaborn as sns

# Clean, single standalone figure setup
plt.figure(figsize=(10, 5))
sns.set_theme(style="whitegrid")

# Calculate yearly average log real price by state
state_yearly = df.groupby(['year', 'state'])['log_real_price'].mean().reset_index()

# Plot standalone line chart comparing Kaduna and Kano
sns.lineplot(
    data=state_yearly, 
    x='year', 
    y='log_real_price', 
    hue='state', 
    marker='s', 
    linewidth=2.5, 
    markersize=7,
    palette=['#1f77b4', '#ff7f0e']  # Blue for Kaduna, Orange for Kano
)

# DRAMATIC EFFECT: Zoom the y-axis to focus tightly on price divergence
min_val = state_yearly['log_real_price'].min() * 0.98
max_val = state_yearly['log_real_price'].max() * 1.02
plt.ylim(min_val, max_val)

# Explicitly label every single year on the x-axis (no decimals like 2012.5)
plt.xticks(state_yearly['year'].unique(), rotation=45, fontweight='bold')

# Formatting
plt.title("Regional Divergence: Kaduna vs. Kano Real Maize Price Trends", fontsize=12, fontweight='bold')
plt.xlabel("Year", fontsize=10)
plt.ylabel("Mean Log Real Price (Zoomed)", fontsize=10)
plt.legend(title="State", frameon=True)

plt.tight_layout()
plt.show()

# %%
#YEARS WITH HEATFLATION SPIKES

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="white")
fig, ax1 = plt.subplots(figsize=(11, 5))

# Calculate yearly averages for rainfall anomaly and log real price
yearly_data = df.groupby('year').agg({
    'current_rfh_anomaly': 'mean',
    'log_real_price': 'mean'
}).reset_index()

# 1. BAR CHART: Rainfall Anomalies (Left Axis)
color_rfh = '#1f77b4'
ax1.set_xlabel('Year', fontweight='bold', fontsize=11)
ax1.set_ylabel('Mean Rainfall Anomaly (mm)', color=color_rfh, fontweight='bold', fontsize=11)
bars = ax1.bar(yearly_data['year'], yearly_data['current_rfh_anomaly'], color=color_rfh, alpha=0.4, width=0.5, label='Rainfall Anomaly')
ax1.tick_params(axis='y', labelcolor=color_rfh)
ax1.axhline(0, color='black', linestyle='--', linewidth=0.8)

# 2. LINE CHART: Log Real Price Trajectory (Right Axis)
ax2 = ax1.twinx()
color_price = '#d62728'
ax2.set_ylabel('Mean Log Real Price', color=color_price, fontweight='bold', fontsize=11)
line = ax2.plot(yearly_data['year'], yearly_data['log_real_price'], color=color_price, marker='o', linewidth=2.5, label='Log Real Price')
ax2.tick_params(axis='y', labelcolor=color_price)

# Formatting
plt.title("Heatflation Dynamics: Rainfall Deficits vs. Maize Price Spikes", fontsize=12, fontweight='bold')
ax1.set_xticks(yearly_data['year'].unique())
ax1.set_xticklabels(yearly_data['year'].unique(), rotation=45, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 5))

years = sorted(df['year'].unique())
rolling_slopes = []

# Calculate 5-year rolling slope of Price on Rainfall
for i in range(len(years) - 4):
    window_years = years[i:i+5]
    sub = df[df['year'].isin(window_years)]
    
    if len(sub) > 5 and sub['current_rfh_anomaly'].std() > 0:
        slope, _ = np.polyfit(sub['current_rfh_anomaly'], sub['log_real_price'], 1)
        rolling_slopes.append({'end_year': window_years[-1], 'slope': slope})

slope_df = pd.DataFrame(rolling_slopes)

# Plot rolling sensitivity coefficient
sns.lineplot(data=slope_df, x='end_year', y='slope', marker='o', color='#d62728', linewidth=2.5)
plt.axhline(0, color='black', linestyle='--', alpha=0.7)

plt.title("Structural Vulnerability: Rolling 5-Year Price Sensitivity to Climate Shocks", fontsize=12, fontweight='bold')
plt.xlabel("End of 5-Year Window", fontsize=10, fontweight='bold')
plt.ylabel("Sensitivity Coefficient (β)\n[Deeper Negative = Worse Heatflation]", fontsize=10)
plt.xticks(slope_df['end_year'].unique(), rotation=45, fontweight='bold')

plt.tight_layout()
plt.show()
